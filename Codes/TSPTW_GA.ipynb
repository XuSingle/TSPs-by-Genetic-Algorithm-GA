# %% [markdown]
# ## We define chromosome_timewindows_penalty() function to compute the penalty

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
# A simple function to compute distance bewteen two citys.
def CacDistance(a,b):
    
    a = np.array(a)
    b = np.array(b)
    c = a-b
    distance = np.sqrt(np.sum(c*c))
    return distance

# Get the Adjacency Matrix
def CityDistance(locs):
        
    n = len(locs)
    dis_mat = np.zeros([len(locs),len(locs)])
    for i in range(n-1):
        for j in range(i+1,n):
            dist = CacDistance(locs[i],locs[j])
            dis_mat[i,j] = dist

    for i in range(n):
        dis_mat[:,i] = dis_mat[i,:]

    return dis_mat

# %%
def chromosome_timewindows_penalty(s):
    current_time = 0
    current_penalty = 0
    
    for gene in s:
        gene_tw = Time_windows[gene]
        if current_time <= gene_tw[1]:
            if current_time <= gene_tw[0]:
                current_time = gene_tw[0]
        else:
            extral_time = gene_tw[1] - current_time
            current_penalty += extral_time * penalty_rate
        
    return current_penalty
    
# A simple function to compute the cost of a chromosome
def cost(s):
    
    
    penalty = chromosome_timewindows_penalty(s)
    
    n = len(s)
    cost = 0
    for i in range(n):
        cost += dis[s[i],s[(i+1)%n]]   
    
    return -cost + penalty   #return negtive value to set a Minimization problem

# A simple function to get each chromosome's fitness in population
def getfitness(population):
    fitness = []
    
    for p in population:
        icost = cost(p)
        fitness.append(icost)
        
    return fitness

# %%
# A simple function to get the third element of list
def TakeThird(element):
    return element[2]


# A function get index of chromosome, chromosome's fitness, pobability, and cumulative probability in adaption
def CacAdap(population):
    # Compute every chromosome‘s fitness in population
    adaption = []
    psum = 0
    i = 0
    for p in population:
        icost = np.exp(cost(p))
        psum += icost
        adaption.append([i])  #add the index of each chromosome
        adaption[i].append(icost) #add the fitness of each chromosome
        i += 1
    
    # Compute the selection probability
    for p in adaption:
        p.append(p[1]/psum)
        p.append(p[2])
        
    # sort adaption by the fitness of each chromosome
    adaption.sort(key=TakeThird,reverse=True)
    
    # Compute the cumulative probability
    n = len(adaption)
    for i in range(1,n):
        p = adaption[i][3] + adaption[i-1][3]
        adaption[i][3] = p
        
        
    return adaption

# %%
def Chose(adaption, population):
    
    #Roulette Whell Selection
    """
    Here we keep the Elite chromosome before selection to prevent some good chromosomes are ignored 
because of Roulette Whell Selection
    """
    best_chromosome = getElite(population)
    
    chose = []
    
    # selection,and get the index of chromosome in population
    epochs = population_init_size 
    n = len(adaption)
    for a in range(epochs):
        p = random.random()
        if adaption[0][3] >= p:
            chose.append(adaption[0][0])
        else:
            for i in range(1,n):
                if adaption[i][3] >= p and adaption[i-1][3] < p:
                    chose.append(adaption[i][0])
                    break
                    
    chose = list((chose))
    
    population_temp = []
    
    for i in chose:
        population_temp.append(population[i])
    
    return population_temp,best_chromosome

# %%
# A function of Crossover
# We need to handle the collision

"""
Here is the basic introduction about how to solve the collision
After we exchange two parts of two chromosomes, we can figure out that all collision genes must exist in exchange part
so that we get the list named collision_a and collision_b
Then we fix two parts of genes left in parent chromosome, that is remaining_a and remaining_b
All we need to do is let length of collision list become 0

If there is a collision, we don't change the exchange part, we just change the remaining part.

Now this is a example to show you how we tackle collision problem.

after crossover, we have:
a = [0,1,{4,3,2,1},6]
b = [6,5,{2,3,4,5},0]
so 1 is a collision in a, so we first find the position of 1 in exchange_genes_b({4,3,2,1}), which is 3
then we get the value of the same position in exchange_genes_a({2,3,4,5}), which is 5
then we set '1' in remaining_a to 5, so a becomes:
a = [0,5,{4,3,2,1},6]
so a has no collision now, so then drop the '1' in collision_a.
This method may induce other collision, so the code will recycle until the length of collision_a becomes 0.
"""

def Cross(p1,p2):
    
    a = p1.copy()
    b = p2.copy()
    # randomly generates two number from 0-9, and I ensure that length of begin to end must larger than 1,
    # if begin = n, end = n+1, than this Crossover operation becomes Mutation
    
    begin = random.randint(0,len(p1)-1)
    end = random.randint(0,len(p1)-1)
    while abs(begin - end) <2:
        begin = random.randint(0,len(p1)-1)
        end = random.randint(0,len(p1)-1)
    # Ensure begin is smaller than end
    if begin > end:
        temp = begin
        begin = end
        end = temp
        
    # get the genes we want to exchange use the slice method of list
    exchange_genes_a = a[begin:end].copy()
    exchange_genes_b = b[begin:end].copy()
    
    collision_a = []
    collision_b = []
    
    # get the collision number in a and b
    for i in exchange_genes_b:
        if i not in exchange_genes_a:
            collision_a.append(i)
            
    for i in exchange_genes_a:
        if i not in exchange_genes_b:
            collision_b.append(i)
            
    # Crossover     
    a[begin:end] = exchange_genes_b
    b[begin:end] = exchange_genes_a
    
    # Handle the collision
    
    # get the remaining part of a
    remaining_a = a[0:begin] + a[end:]
    while len(collision_a) > 0:
        temp = exchange_genes_a[exchange_genes_b.index(collision_a[-1])]
        remaining_a[remaining_a.index(collision_a[-1])] = temp
        if remaining_a.count(collision_a[-1]) == 0:
            collision_a.pop()
        if temp in exchange_genes_b and temp in remaining_a:
            collision_a.append(temp)
            
    # recover a by remaining_a which is containing no collision
    a[0:begin] = remaining_a[0:begin]
    a[end:] = remaining_a[begin:]
    
    # as the same as a
    remaining_b = b[0:begin] + b[end:]
    while len(collision_b) > 0:
        temp = exchange_genes_b[exchange_genes_a.index(collision_b[-1])]
        remaining_b[remaining_b.index(collision_b[-1])] = temp
        
        if remaining_b.count(collision_b[-1]) == 0:
            collision_b.pop()
        
        if temp in exchange_genes_a and temp in remaining_b:
            collision_b.append(temp)
    
    b[0:begin] = remaining_b[0:begin]
    b[end:] = remaining_b[begin:]
    

    return a,b

# %%
# A simple function of Mutation, just swap two genes
def Mutation(s):
    c = range(len(s))
    index1,index2 = random.sample(c,2)
    temp = s[index1]
    s[index1] = s[index2]
    s[index2] = temp
    return s

# %%
def Crossover_Mutation(population, best_chromosome, current_crossover_rate, current_mutation_rate):
    
    # Compute the number of chromosome we need to crossover and mutation
    number_of_crossover = int(math.ceil(current_crossover_rate * len(population)))
    number_of_mutation = int(math.ceil(current_mutation_rate * len(population)))
    
    # To store the child of crossover and mutation
    temp_chromosome = []
    
    # Crossover operation
    for i in range(number_of_crossover//2):
        index1,index2 = random.sample(range(0,len(population)),2)
        parent1 = population[index1].copy()
        parent2 = population[index2].copy()
        child1,child2 = Cross(parent1,parent2)
        temp_chromosome.append(list(child1))
        temp_chromosome.append(list(child2))
        
    # Mutation operation 
    for i in range(number_of_mutation):
        mutation_index = random.sample(range(0,len(population)),1)
        mutation_parent = population[mutation_index[0]].copy()
        mutation_child = Mutation(mutation_parent)
        temp_chromosome.append(mutation_child)
        
    # Append the child into population
    for i in temp_chromosome:
        population.append(i)
    
    # Append the best chromosome before selection into population
    population = addelite(population,best_chromosome)

        
    return population

# %%
def addelite(population, best_chromosome):
    
    population_fitness = getfitness(population)
    elite_fitness = getfitness(best_chromosome)
    
    while len(elite_fitness) != 0 and min(population_fitness) < max(elite_fitness) :
        
        index_min_pop = population_fitness.index(min(population_fitness))
        index_max_elite = elite_fitness.index(max(elite_fitness))
        
        population[index_min_pop] = best_chromosome[index_max_elite]
        
        population_fitness[index_min_pop] = 9999999
        elite_fitness.remove(elite_fitness[index_max_elite])
    
    
    return population

# %%
# A simple funtion to get Elite chromosome in current population
def getElite(population):
    
    len_elite = int(math.ceil(elite_keep_rate * len(population)))
    if len_elite < 1 :
        len_elite = 1
    
    adaption = getfitness(population)

    best_chromosome = []
    best_chromosome_index = list(np.argsort(adaption)[::-1][:len_elite])

    for i in best_chromosome_index:
        best_chromosome.append(population[i])
        
    return best_chromosome

# %%
def GA(population, current_crossover_rate, current_mutation_rate):
    
    # get the adaption
    adaption = CacAdap(population)

    # choose chromosome base on Roulette Whell Selection
    population, best_chromosome = Chose(adaption, population)

    # Crossover and Mutation in population
    population = Crossover_Mutation(population, best_chromosome, current_crossover_rate, current_mutation_rate)
        

    return population

# %%
def find_min(population, iteration):
    loss = []
    i = 0
    j = 0

    current_crossover_rate = crossover_rate
    current_mutation_rate = mutation_rate
    current_best_fitness = max(getfitness(population))
    
    while i < iteration:
        
        fitness = getfitness(population)
        min_cost = max(fitness)
        
        if current_best_fitness == min_cost:
            j = j + 1
        else:
            current_best_fitness = min_cost
            current_crossover_rate = crossover_rate
            current_mutation_rate = mutation_rate
            j = 0
        
        if j==5:
            if current_crossover_rate + 0.05 < 1 :
                current_crossover_rate += 0.05
        if j==10:
            if current_crossover_rate + 0.05 < 1 :
                current_crossover_rate += 0.05
            if current_mutation_rate + 0.05 < 1:
                current_mutation_rate += 0.05
            j=0
        
        # begin iteration
        population = GA(population, current_crossover_rate, current_mutation_rate)

        min_cost = max(fitness)
        if i%10 == 0:
            print('iteration %d: loss=%.2f'%(i,-min_cost))
        loss.append([i,-min_cost])
        i += 1
        
        #print the best result
        if i == iteration:
            p_len = len(population)
            for index in range(p_len):
                if fitness[index] == min_cost:
                    print('Optimal path:')
                    print(population[index])
                    print('Optimal cost:')
                    print(-min_cost)
                    break
    # print the plot of how the cost function goes
    loss = np.array(loss)
    plt.plot(loss[:,0],loss[:,1])
    plt.title('TSPTW')
    plt.savefig('TSPTW.png', dpi=600)
    plt.show()

# %%
# HyperParameters
penalty_rate = 0.001        #the rate of penalty if arrive a city over the due time
city_number = 101           #the number of cities
population_init_size = 250  #the population size
elite_keep_rate = 0.15      #define how much elite will be kept
iteration_times = 2001       #times of iteration
crossover_rate = 0.8        #rate of crossover
mutation_rate = 0.2        #rate of mutation


# randomly generates population
population = []
for i in range(0,population_init_size):
    population.append(list(range(0,city_number)))
    random.shuffle(population[i])
    
# get the dataset from csv
TSP_df = pd.read_csv('/Users/singlexu/Desktop/Artificial Intelligence Concepts/Project 1/Dataset/TSPTW_dataset.csv')
TSP_df = TSP_df.drop(columns=["CUST_NO", "DEMAND"])

# get the normalized city location
City_location = TSP_df[['XCOORD','YCOORD']]
City_location = round((City_location-City_location.min())/(City_location.max()-City_location.min()), 4)

locs = []
for i in range(len(City_location)):
    locs.append((City_location['XCOORD'][i],City_location['YCOORD'][i]))

#get the Adjacency Matrix of the citys
dis = CityDistance(locs)

# get each city's time window
Time_windows = []
for i in range(len(TSP_df)):
    Time_windows.append((TSP_df['READY_TIME'][i],TSP_df['DUE_DATE'][i]))

# main function 
find_min(population, iteration_times)
# Out:
# iteration 0: loss=80.94
# iteration 10: loss=67.14
# iteration 20: loss=62.61
# iteration 30: loss=59.15
# iteration 40: loss=56.52
# iteration 50: loss=52.46
# iteration 60: loss=50.46
# iteration 70: loss=48.55
# iteration 80: loss=46.97
# iteration 90: loss=44.29
# iteration 100: loss=41.20
# iteration 110: loss=40.45
# iteration 120: loss=38.89
# iteration 130: loss=37.96
# iteration 140: loss=36.99
# iteration 150: loss=35.82
# iteration 160: loss=35.17
# iteration 170: loss=34.48
# iteration 180: loss=33.14
# iteration 190: loss=32.71
# iteration 200: loss=32.24
# iteration 210: loss=31.58
# iteration 220: loss=30.97
# iteration 230: loss=30.74
# iteration 240: loss=30.16
# iteration 250: loss=29.69
# iteration 260: loss=29.28
# iteration 270: loss=28.95
# iteration 280: loss=28.79
# iteration 290: loss=28.55
# iteration 300: loss=28.37
# iteration 310: loss=28.17
# iteration 320: loss=28.11
# iteration 330: loss=28.08
# iteration 340: loss=27.94
# iteration 350: loss=27.79
# iteration 360: loss=27.75
# iteration 370: loss=27.42
# iteration 380: loss=27.38
# iteration 390: loss=27.18
# iteration 400: loss=26.95
# iteration 410: loss=26.63
# iteration 420: loss=26.62
# iteration 430: loss=26.36
# iteration 440: loss=26.04
# iteration 450: loss=25.99
# iteration 460: loss=25.82
# iteration 470: loss=25.57
# iteration 480: loss=25.43
# iteration 490: loss=25.33
# iteration 500: loss=25.22
# iteration 510: loss=25.16
# iteration 520: loss=24.99
# iteration 530: loss=24.91
# iteration 540: loss=24.77
# iteration 550: loss=24.69
# iteration 560: loss=24.63
# iteration 570: loss=24.40
# iteration 580: loss=24.35
# iteration 590: loss=24.27
# iteration 600: loss=24.25
# iteration 610: loss=24.11
# iteration 620: loss=24.00
# iteration 630: loss=23.98
# iteration 640: loss=23.98
# iteration 650: loss=23.87
# iteration 660: loss=23.81
# iteration 670: loss=23.81
# iteration 680: loss=23.72
# iteration 690: loss=23.72
# iteration 700: loss=23.64
# iteration 710: loss=23.64
# iteration 720: loss=23.62
# iteration 730: loss=23.62
# iteration 740: loss=23.62
# iteration 750: loss=23.62
# iteration 760: loss=23.58
# iteration 770: loss=23.58
# iteration 780: loss=23.58
# iteration 790: loss=23.58
# iteration 800: loss=23.58
# iteration 810: loss=23.52
# iteration 820: loss=23.44
# iteration 830: loss=23.44
# iteration 840: loss=23.44
# iteration 850: loss=23.44
# iteration 860: loss=23.44
# iteration 870: loss=23.44
# iteration 880: loss=23.44
# iteration 890: loss=23.41
# iteration 900: loss=23.41
# iteration 910: loss=23.41
# iteration 920: loss=23.41
# iteration 930: loss=23.39
# iteration 940: loss=23.38
# iteration 950: loss=23.35
# iteration 960: loss=23.31
# iteration 970: loss=23.31
# iteration 980: loss=23.31
# iteration 990: loss=23.30
# iteration 1000: loss=23.30
# iteration 1010: loss=23.30
# iteration 1020: loss=23.30
# iteration 1030: loss=23.15
# iteration 1040: loss=23.14
# iteration 1050: loss=23.14
# iteration 1060: loss=23.14
# iteration 1070: loss=23.14
# iteration 1080: loss=23.14
# iteration 1090: loss=23.14
# iteration 1100: loss=23.14
# iteration 1110: loss=23.14
# iteration 1120: loss=23.14
# iteration 1130: loss=23.14
# iteration 1140: loss=23.14
# iteration 1150: loss=23.14
# iteration 1160: loss=23.14
# iteration 1170: loss=23.14
# iteration 1180: loss=23.14
# iteration 1190: loss=23.14
# iteration 1200: loss=23.14
# iteration 1210: loss=23.14
# iteration 1220: loss=23.14
# iteration 1230: loss=23.14
# iteration 1240: loss=23.14
# iteration 1250: loss=23.14
# iteration 1260: loss=23.14
# iteration 1270: loss=23.14
# iteration 1280: loss=23.14
# iteration 1290: loss=23.14
# iteration 1300: loss=23.14
# iteration 1310: loss=23.14
# iteration 1320: loss=23.14
# iteration 1330: loss=23.14
# iteration 1340: loss=23.14
# iteration 1350: loss=23.14
# iteration 1360: loss=23.14
# iteration 1370: loss=23.14
# iteration 1380: loss=23.14
# iteration 1390: loss=23.14
# iteration 1400: loss=23.14
# iteration 1410: loss=23.14
# iteration 1420: loss=23.14
# iteration 1430: loss=23.14
# iteration 1440: loss=23.14
# iteration 1450: loss=23.14
# iteration 1460: loss=23.14
# iteration 1470: loss=23.14
# iteration 1480: loss=23.14
# iteration 1490: loss=23.14
# iteration 1500: loss=23.14
# iteration 1510: loss=23.14
# iteration 1520: loss=23.14
# iteration 1530: loss=23.14
# iteration 1540: loss=23.14
# iteration 1550: loss=23.14
# iteration 1560: loss=23.14
# iteration 1570: loss=23.14
# iteration 1580: loss=23.14
# iteration 1590: loss=23.14
# iteration 1600: loss=23.14
# iteration 1610: loss=23.14
# iteration 1620: loss=23.14
# iteration 1630: loss=23.14
# iteration 1640: loss=23.14
# iteration 1650: loss=23.14
# iteration 1660: loss=23.14
# iteration 1670: loss=23.14
# iteration 1680: loss=23.14
# iteration 1690: loss=23.14
# iteration 1700: loss=23.14
# iteration 1710: loss=23.14
# iteration 1720: loss=23.14
# iteration 1730: loss=23.14
# iteration 1740: loss=23.14
# iteration 1750: loss=23.14
# iteration 1760: loss=23.14
# iteration 1770: loss=23.14
# iteration 1780: loss=23.14
# iteration 1790: loss=23.14
# iteration 1800: loss=23.14
# iteration 1810: loss=23.14
# iteration 1820: loss=23.14
# iteration 1830: loss=23.14
# iteration 1840: loss=23.14
# iteration 1850: loss=23.14
# iteration 1860: loss=23.14
# iteration 1870: loss=23.14
# iteration 1880: loss=23.14
# iteration 1890: loss=23.14
# iteration 1900: loss=23.14
# iteration 1910: loss=23.14
# iteration 1920: loss=23.14
# iteration 1930: loss=23.14
# iteration 1940: loss=23.14
# iteration 1950: loss=23.14
# iteration 1960: loss=23.14
# iteration 1970: loss=23.14
# iteration 1980: loss=23.14
# iteration 1990: loss=23.14
# iteration 2000: loss=23.14
# Optimal path:
# [37, 24, 44, 2, 51, 6, 60, 78, 85, 8, 39, 68, 15, 10, 83, 81, 45, 28, 73, 14, 36, 29, 49, 75, 80, 79, 42, 50, 54, 26, 19, 61, 98, 17, 32, 90, 9, 33, 58, 7, 25, 86, 84, 56, 88, 23, 92, 47, 53, 72, 59, 11, 65, 95, 1, 3, 18, 12, 5, 70, 30, 71, 93, 4, 64, 31, 35, 52, 34, 13, 97, 62, 96, 77, 40, 21, 87, 67, 82, 43, 41, 16, 55, 20, 48, 74, 27, 76, 46, 63, 22, 38, 57, 94, 69, 91, 66, 99, 100, 89, 0]
# Optimal cost:
# 23.136236558721322
